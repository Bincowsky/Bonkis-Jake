# %%
df.head()
# Out:
#         brand  che_pc_usd  che_perc_gdp               cluster_nl corporation  \
# 0  BRAND_354E    1.209114      1.665879  BRAND_354E_COUNTRY_88A3   CORP_D524
# 1  BRAND_626D   -1.000000     -1.000000  BRAND_626D_COUNTRY_8B47   CORP_01C7
# 2  BRAND_45D9    1.209114      1.665879  BRAND_45D9_COUNTRY_88A3   CORP_39F7
# 3  BRAND_D724    1.851280      2.051770  BRAND_D724_COUNTRY_445D   CORP_711A
# 4  BRAND_4887    1.791199      2.059130  BRAND_4887_COUNTRY_D8B0   CORP_443D
#
#         country launch_date        date       drug_id      ind_launch_date  \
# 0  COUNTRY_88A3  2014-06-01  2014-06-01  DRUG_ID_8795                   -1
# 1  COUNTRY_8B47  2014-06-01  2014-06-01  DRUG_ID_E66E  2014-09-01 00:00:00
# 2  COUNTRY_88A3  2014-06-01  2014-06-01  DRUG_ID_F272                   -1
# 3  COUNTRY_445D  2014-06-01  2014-06-01  DRUG_ID_1D4E                   -1
# 4  COUNTRY_D8B0  2014-06-01  2014-06-01  DRUG_ID_AA88                   -1
#
# ...

# %%
import pandas as pd

df = pd.read_csv('../data/raw/train_data.csv')
clusterdf = df[['brand', 'country', 'che_pc_usd', 'che_perc_gdp', 'population', 'date', 'target' ]]

clusterdf.head()

# Select rows where 'che_pc_usd', 'che_perc_gdp', or 'population' is -1
invalid_entries = clusterdf[
    (clusterdf['che_pc_usd'] == -1) |
    (clusterdf['che_perc_gdp'] == -1) |
    (clusterdf['population'] == -1)
]

# Display the filtered rows
invalid_entries
# Out:
#              brand       country  che_pc_usd  che_perc_gdp  population  \
# 1       BRAND_626D  COUNTRY_8B47   -1.000000          -1.0    1.023562
# 7       BRAND_626D  COUNTRY_5180    1.237984          -1.0    1.050796
# 19      BRAND_626D  COUNTRY_5180    1.237984          -1.0    1.050796
# 23      BRAND_626D  COUNTRY_8B47   -1.000000          -1.0    1.023562
# 58      BRAND_626D  COUNTRY_8B47   -1.000000          -1.0    1.023562
# ...            ...           ...         ...           ...         ...
# 118827  BRAND_AA1F  COUNTRY_8B47   -1.000000          -1.0    1.025199
# 118851  BRAND_2058  COUNTRY_5180    1.340020          -1.0    1.051939
# 118882  BRAND_D786  COUNTRY_8B47   -1.000000          -1.0    1.025199
# 118907  BRAND_F148  COUNTRY_8B47   -1.000000          -1.0    1.025199
# 118909  BRAND_76D6  COUNTRY_5180    1.340020          -1.0    1.051939
#
#               date    target
# 1       2014-06-01  1.000000
# 7       2014-06-01  1.002721
# ...

# %%
# Ensure 'date' is in datetime format
clusterdf['date'] = pd.to_datetime(clusterdf['date'])

# Extract month from 'date'
clusterdf['month'] = clusterdf['date'].dt.month

grouped_df = clusterdf.groupby(['country', 'brand', 'month']).mean().reset_index()

grouped_df.head()
# Out:
# C:\Users\adria\AppData\Local\Temp\ipykernel_22492\1406434861.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clusterdf['date'] = pd.to_datetime(clusterdf['date'])
# C:\Users\adria\AppData\Local\Temp\ipykernel_22492\1406434861.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clusterdf['month'] = clusterdf['date'].dt.month
#         country       brand  month  che_pc_usd  che_perc_gdp  population  \
# 0  COUNTRY_0309  BRAND_0056      1    1.721203      1.950801    1.496017
# ...
